# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaShishikina/stepik/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.groupby('gender').aggregate ({'writing score':'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %% [markdown]
# отбор первые 5 наблюдений и 3 колонки

# %%
df.iloc[0:5,0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %% [markdown]
# отбор нулевая, третья и 10 строчки и столбцы 1,3 и 5

# %%
df.iloc[[0,3,10],[1,3,-1]]
# Out:
#    race/ethnicity         lunch  writing score
# 0         group B      standard             74
# 3         group A  free/reduced             44
# 10        group C      standard             52

# %% [markdown]
# изменим индекс

# %%
df2=df.iloc[[0,3,4,7,8]]
df2
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
df2.index= ["Cersei","Tywin","Gregor","Joffrey","Ilyn Payne"]
df2
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
df2.loc[['Cersei','Tywin']]
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Cersei  female        group B           bachelor's degree      standard
# Tywin     male        group A          associate's degree  free/reduced
#
#        test preparation course  math score  reading score  writing score
# Cersei                    none          72             72             74
# Tywin                     none          47             57             44

# %% [markdown]
# все строки первой колонки

# %%
df2.iloc[ : ,0]
# Out:
# Cersei        female
# Tywin           male
# Gregor          male
# Joffrey         male
# Ilyn Payne      male
# Name: gender, dtype: object

# %%
type (df2.iloc[ : ,0])
# Out:
# pandas.core.series.Series

# %%
df2['gender']
# Out:
# Cersei        female
# Tywin           male
# Gregor          male
# Joffrey         male
# Ilyn Payne      male
# Name: gender, dtype: object

# %%
df2[['gender']]
# Out:
#             gender
# Cersei      female
# Tywin         male
# Gregor        male
# Joffrey       male
# Ilyn Payne    male

# %%
df2.iloc[0:3]
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Cersei  female        group B           bachelor's degree      standard
# Tywin     male        group A          associate's degree  free/reduced
# Gregor    male        group C                some college      standard
#
#        test preparation course  math score  reading score  writing score
# Cersei                    none          72             72             74
# Tywin                     none          47             57             44
# Gregor                    none          76             78             75

# %% [markdown]
# gender = female

# %%
df.gender=='female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
df.loc[df.gender=='female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[df.gender=='female',['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 5    female          71
# 6    female          88
# ..      ...         ...
# 993  female          62
# 995  female          88
# 997  female          59
# 998  female          68
# 999  female          77
#
# [518 rows x 2 columns]

# %% [markdown]
# выведем тех у кого мат балл выше среднего

# %%
df['math score'].mean()
# Out:
# 66.089

# %%
df.loc[df['math score']>df['math score'].mean(),['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 4      male          76
# 5    female          71
# ..      ...         ...
# 989  female          67
# 990    male          86
# 995  female          88
# 998  female          68
# 999  female          77
#
# [493 rows x 2 columns]

# %%
df.loc[(df['math score']>df['math score'].mean())&(df.gender=='female'),['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 5    female          71
# 6    female          88
# ..      ...         ...
# 984  female          74
# 989  female          67
# 995  female          88
# 998  female          68
# 999  female          77
#
# [221 rows x 2 columns]

# %%
query = (df['math score']>df['math score'].mean())&(df.gender=='female')
df.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
query = (df['math score']>df['math score'].mean())&(df.gender=='female')
df.loc[query,['gender','math score']].head()
# Out:
#    gender  math score
# 0  female          72
# 1  female          69
# 2  female          90
# 5  female          71
# 6  female          88

# %% [markdown]
# У какой доли студентов из датасэта в колонке lunch указано free/reduced?
#
# Формат ответа десятичная дробь, например, 0.25

# %%
x = (df.loc[df.lunch=='free/reduced'].shape[0])/df.shape[0]
x
# Out:
# 0.355

# %%
df.loc[df.lunch=='free/reduced'].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df.loc[df.lunch=='standard'].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
df= df\
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.query("writing_score>74")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.query("gender=='female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.query("gender=='female'& writing_score>78")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
x=78

# %% [markdown]
# df.query("writing_score>x")  не сработает!!

# %%
df.query("writing_score>@x")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df[df['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# вывести названия колонок

# %%
list(df)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %% [markdown]
# колонки содержащие score  в названии

# %%
[i for i in list(df) if 'score' in i]
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
score  = [i for i in list(df) if 'score' in i]

# %%
df[score].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# более пандас вей

# %%
df.filter(like='score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# фильтр можно применять не только по столбцам но и по  строкам/ для этого есть axis. axis=1 = columns, axis= 0 rows

# %%
df2.filter(like='e')
# Out:
#             gender race/ethnicity parental level of education  \
# Cersei      female        group B           bachelor's degree
# Tywin         male        group A          associate's degree
# Gregor        male        group C                some college
# Joffrey       male        group B                some college
# Ilyn Payne    male        group D                 high school
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
df2.filter(like='e',axis=0)
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %% [markdown]
# 1.6 group by, aggregate

# %% [markdown]
# среднее значит скоров в зависимости от пола

# %%
df.groupby('gender').mean()
# Out:
# <ipython-input-45-f7bed15d94f3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('gender').mean()
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
df.groupby('gender').aggregate({'math_score':'mean','reading_score':'mean'})
# Out:
#         math_score  reading_score
# gender
# female   63.633205      72.608108
# male     68.728216      65.473029

# %% [markdown]
# если не нравится индекс есть аргумент as_index

# %%
df.groupby('gender',as_index=False).aggregate({'math_score':'mean','reading_score':'mean'})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
df.groupby(['gender','race/ethnicity'],as_index=False).aggregate({'math_score':'mean','reading_score':'mean'})
# Out:
#    gender race/ethnicity  math_score  reading_score
# 0  female        group A   58.527778      69.000000
# 1  female        group B   61.403846      71.076923
# 2  female        group C   62.033333      71.944444
# 3  female        group D   65.248062      74.046512
# 4  female        group E   70.811594      75.840580
# 5    male        group A   63.735849      61.735849
# 6    male        group B   65.930233      62.848837
# 7    male        group C   67.611511      65.424460
# 8    male        group D   69.413534      66.135338
# 9    male        group E   76.746479      70.295775

# %% [markdown]
# вывести уникальные значения

# %%
df.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %% [markdown]
# число уникальных значений

# %%
df.math_score.nunique()
# Out:
# 81

# %%
df.groupby(['gender','race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %% [markdown]
# топ 5 маематиков девушек и топ 5 математиков юношей

# %%
df.sort_values(['gender','math_score'])
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 306    male        group E                some college      standard
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.sort_values(['gender','math_score'],ascending=False)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.sort_values(['gender','math_score'],ascending=False)\
.groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
df['total_score'] = df.math_score+df.reading_score+df.writing_score

# %%
df=df.assign(total_score_log=np.log(df.total_score))

# %%
df.drop(['total_score','lunch'],axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education  \
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
dota = pd.read_csv('dota_hero_stats.csv')
dota.head()
dota.groupby(['legs']).nunique()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11            2  11              11    11             3     11
# 2             95            2  95              95    95             3     81
# 4              7            2   7               7     7             3      7
# 6              3            2   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
dota.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
dota.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
dota.groupby('legs').count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
[len(dota[dota.legs == i]) for i in [0,2,4,6,8]]
# Out:
# [11, 95, 7, 3, 1]

# %% [markdown]
# test

# %%
lupa = pd.read_csv("accountancy.csv")
lupa.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-6728cf37f880> in <cell line: 1>()
# ----> 1 lupa = pd.read_csv("accountancy.csv")
#       2 lupa.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
lupa.groupby(['Type','Executor'])['Salary'].mean()

# %% [markdown]
# test

# %%
dota.groupby(['attack_type','primary_attr']).count().head()

# %% [markdown]
# test

# %%
concentrations =pd.read_csv('algae.csv')
concentrations .head()
concentrations.groupby('genus').mean()

# %%
concentrations .head()

# %%
concentrations.query('genus == "Fucus"')['alanin'].describe().round(2)

# %% [markdown]
# Дисперсия концентрации цитрата в бурых, зелёных и красных водорослях

# %%
concentrations.groupby('group')\
                        [['citrate']]\
                        .describe()\
                        .round(2)

# %%
concentrations.groupby('group').aggregate({'citrate':'var'})

# %%
concentrations.groupby('group').aggregate({'sucrose':'max'})-concentrations.groupby('group').aggregate({'sucrose':'min'})

# %%
concentrations.groupby('group').count()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.math_score.hist()

# %%
df.plot.scatter(x='math_score',y='reading_score')

# %%
sns.lmplot(x='math_score',y='reading_score',hue='gender',data=df)

# %%
a=sns.lmplot(x='math_score',y='reading_score',hue='gender',data=df,fit_reg=False)

# %%
a=sns.lmplot(x='math_score',y='reading_score',hue='gender',data=df,fit_reg=False)

a.set_xlabels('Math Score')
a.set_xlabels('Reading Score')

# %% [markdown]
# 1.7 Тест

# %%
inc=pd.read_csv("income.csv")
inc

# %%
# Out:
# 0                         ['Carry', 'Escape', 'Nuker']
# 1      ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          ['Support', 'Disabler', 'Nuker', 'Durable']
# 3    ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          ['Support', 'Disabler', 'Nuker', 'Jungler']
# Name: roles, dtype: object

# %%
inc.income.plot()

# %%
import pandas as pd
import seaborn as sns
gm=pd.read_csv("genome_matrix.csv")
gm.head()

# %%
s=pd.read_csv('genome_matrix.csv',index_col=0)

g=sns.heatmap(data=s, cmap='viridis')

g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles  q
# 0                       ['Carry', 'Escape', 'Nuker']  3
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']  4
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']  4
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...  5
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']  4

# %%
dota['q'] = dota['roles'].str.count(',') + 1

# %%
dota.q.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.distplot([x.count(',')+1 for x in dota.roles], bins=15)
# Out:
# <ipython-input-72-bd63ebdcbdcd>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([x.count(',')+1 for x in dota.roles], bins=15)
# <Axes: ylabel='Density'>

# %%
dota.roles.map(eval).map(len).mode()
# Out:
# 0    4
# Name: roles, dtype: int64
